# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb

from sklearn import (
    model_selection,
    metrics,
    linear_model,
    ensemble,
    svm
)

# %%
SEED = 42
np.random.seed(SEED)

# %% [markdown]
# # Data Processing

# %%
dataset = pd.read_csv('boston.csv')
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
dataset.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
dataset.describe(include='all').T.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_1816d_row0_col0, #T_1816d_row0_col3, #T_1816d_row0_col4, #T_1816d_row0_col5, #T_1816d_row1_col0, #T_1816d_row1_col3, #T_1816d_row1_col4, #T_1816d_row1_col5, #T_1816d_row2_col0, #T_1816d_row2_col3, #T_1816d_row3_col0, #T_1816d_row3_col1, #T_1816d_row3_col2, #T_1816d_row3_col3, #T_1816d_row3_col4, #T_1816d_row3_col5, #T_1816d_row3_col6, #T_1816d_row3_col7, #T_1816d_row4_col0, #T_1816d_row4_col1, #T_1816d_row4_col2, #T_1816d_row4_col3, #T_1816d_row4_col4, #T_1816d_row4_col5, #T_1816d_row4_col6, #T_1816d_row4_col7, #T_1816d_row5_col0, #T_1816d_row5_col2, #T_1816d_row6_col0, #T_1816d_row7_col0, #T_1816d_row8_col0, #T_1816d_row9_col0, #T_1816d_row10_col0, #T_1816d_row11_col0, #T_1816d_row11_col3, #T_1816d_row12_col0, #T_1816d_row13_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_1816d_row0_col1, #T_1816d_row5_col6, #T_1816d_row5_col7, #T_1816d_row7_col1, #T_1816d_row7_col5, #T_1816d_row8_col4, #T_1816d_row12_col3 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_1816d_row0_col2, #T_1816d_row10_col1, #T_1816d_row10_col4, #T_1816d_row10_col5, #T_1816d_row13_col4 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_1816d_row0_col6, #T_1816d_row7_col3, #T_1816d_row7_col4, #T_1816d_row7_col6, #T_1816d_row8_col3 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_1816d_row0_col7 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_1816d_row1_col1, #T_1816d_row10_col6, #T_1816d_row10_col7, #T_1816d_row12_col1, #T_1816d_row12_col5 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_1816d_row1_col2, #T_1816d_row1_col7, #T_1816d_row6_col7 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_1816d_row1_col6, #T_1816d_row5_col3, #T_1816d_row5_col4, #T_1816d_row5_col5, #T_1816d_row7_col7, #T_1816d_row12_col4 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_1816d_row2_col1, #T_1816d_row2_col5, #T_1816d_row2_col6, #T_1816d_row12_col6, #T_1816d_row13_col3 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_1816d_row2_col2, #T_1816d_row12_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_1816d_row2_col4, #T_1816d_row5_col1, #T_1816d_row6_col3, #T_1816d_row7_col2, #T_1816d_row8_col5, #T_1816d_row10_col2 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_1816d_row2_col7, #T_1816d_row8_col6, #T_1816d_row13_col6 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_1816d_row6_col1, #T_1816d_row6_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_1816d_row6_col4 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_1816d_row6_col5 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_1816d_row6_col6 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_1816d_row8_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_1816d_row8_col2, #T_1816d_row12_col7, #T_1816d_row13_col2, #T_1816d_row13_col5 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_1816d_row8_col7 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_1816d_row9_col1, #T_1816d_row9_col2, #T_1816d_row9_col3, #T_1816d_row9_col6, #T_1816d_row9_col7, #T_1816d_row11_col4, #T_1816d_row11_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_1816d_row9_col4 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_1816d_row9_col5 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_1816d_row10_col3, #T_1816d_row13_col7 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_1816d_row11_col1 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_1816d_row11_col2 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_1816d_row11_col6 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_1816d_row11_col7 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_1816d_row13_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# </style>
# <table id="T_1816d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1816d_level0_row0" class="row_heading level0 row0" >CRIM</th>
#       <td id="T_1816d_row0_col0" class="data row0 col0" >506.000000</td>
#       <td id="T_1816d_row0_col1" class="data row0 col1" >3.613524</td>
#       <td id="T_1816d_row0_col2" class="data row0 col2" >8.601545</td>
#       <td id="T_1816d_row0_col3" class="data row0 col3" >0.006320</td>
#       <td id="T_1816d_row0_col4" class="data row0 col4" >0.082045</td>
#       <td id="T_1816d_row0_col5" class="data row0 col5" >0.256510</td>
#       <td id="T_1816d_row0_col6" class="data row0 col6" >3.677083</td>
#       <td id="T_1816d_row0_col7" class="data row0 col7" >88.976200</td>
#     </tr>
#     <tr>
#       <th id="T_1816d_level0_row1" class="row_heading level0 row1" >ZN</th>
#       <td id="T_1816d_row1_col0" class="data row1 col0" >506.000000</td>
#       <td id="T_1816d_row1_col1" class="data row1 col1" >11.363636</td>
#       <td id="T_1816d_row1_col2" class="data row1 col2" >23.322453</td>
#       <td id="T_1816d_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_1816d_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_1816d_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_1816d_row1_col6" class="data row1 col6" >12.500000</td>
#       <td id="T_1816d_row1_col7" class="data row1 col7" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1816d_level0_row2" class="row_heading level0 row2" >INDUS</th>
#       <td id="T_1816d_row2_col0" class="data row2 col0" >506.000000</td>
#       <td id="T_1816d_row2_col1" class="data row2 col1" >11.136779</td>
#       <td id="T_1816d_row2_col2" class="data row2 col2" >6.860353</td>
#       <td id="T_1816d_row2_col3" class="data row2 col3" >0.460000</td>
#       <td id="T_1816d_row2_col4" class="data row2 col4" >5.190000</td>
#       <td id="T_1816d_row2_col5" class="data row2 col5" >9.690000</td>
#       <td id="T_1816d_row2_col6" class="data row2 col6" >18.100000</td>
#       <td id="T_1816d_row2_col7" class="data row2 col7" >27.740000</td>
#     </tr>
#     <tr>
#       <th id="T_1816d_level0_row3" class="row_heading level0 row3" >CHAS</th>
#       <td id="T_1816d_row3_col0" class="data row3 col0" >506.000000</td>
#       <td id="T_1816d_row3_col1" class="data row3 col1" >0.069170</td>
#       <td id="T_1816d_row3_col2" class="data row3 col2" >0.253994</td>
#       <td id="T_1816d_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_1816d_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_1816d_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_1816d_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_1816d_row3_col7" class="data row3 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1816d_level0_row4" class="row_heading level0 row4" >NOX</th>
#       <td id="T_1816d_row4_col0" class="data row4 col0" >506.000000</td>
#       <td id="T_1816d_row4_col1" class="data row4 col1" >0.554695</td>
#       <td id="T_1816d_row4_col2" class="data row4 col2" >0.115878</td>
#       <td id="T_1816d_row4_col3" class="data row4 col3" >0.385000</td>
#       <td id="T_1816d_row4_col4" class="data row4 col4" >0.449000</td>
#       <td id="T_1816d_row4_col5" class="data row4 col5" >0.538000</td>
#       <td id="T_1816d_row4_col6" class="data row4 col6" >0.624000</td>
#       <td id="T_1816d_row4_col7" class="data row4 col7" >0.871000</td>
#     </tr>
#     <tr>
#       <th id="T_1816d_level0_row5" class="row_heading level0 row5" >RM</th>
#       <td id="T_1816d_row5_col0" class="data row5 col0" >506.000000</td>
#       <td id="T_1816d_row5_col1" class="data row5 col1" >6.284634</td>
#       <td id="T_1816d_row5_col2" class="data row5 col2" >0.702617</td>
#       <td id="T_1816d_row5_col3" class="data row5 col3" >3.561000</td>
#       <td id="T_1816d_row5_col4" class="data ro

# %% [markdown]
# #### check is data has null or value

# %%
dataset.isnull().mean() * 100
# Out:
# CRIM       0.0
# ZN         0.0
# INDUS      0.0
# CHAS       0.0
# NOX        0.0
# RM         0.0
# AGE        0.0
# DIS        0.0
# RAD        0.0
# TAX        0.0
# PTRATIO    0.0
# B          0.0
# LSTAT      0.0
# MEDV       0.0
# dtype: float64

# %% [markdown]
# ### correlation of the data

# %%
corr_mat = dataset.corr()

# %%
sns.heatmap(corr_mat,annot=True,fmt='1.1f')
# Out:
# <AxesSubplot:>

# %%
for x in range(corr_mat.shape[0]):
    corr_mat.iloc[x,x] = 0.0
    
corr_mat.abs().idxmax()
# Out:
# CRIM         RAD
# ZN           DIS
# INDUS        NOX
# CHAS        MEDV
# NOX          DIS
# RM          MEDV
# AGE          DIS
# DIS          NOX
# RAD          TAX
# TAX          RAD
# PTRATIO     MEDV
# B            RAD
# LSTAT       MEDV
# MEDV       LSTAT
# dtype: object

# %%
sns.pairplot(corr_mat)

# %% [markdown]
# #### Average number of rooms per dwelling

# %%
RM = pd.cut(dataset['RM'],bins=3,labels = ['Low','Medium','High'])
RM.value_counts().plot.bar(title = 'Average Number of Rooms Per Dwelling')
# Out:
# <AxesSubplot:title={'center':'Average Number of Rooms Per Dwelling'}>

# %% [markdown]
# ### MEDV vs RM

# %%
sns.lmplot(x="MEDV",y="RM",data=dataset)

# %% [markdown]
# ### MEDV distribution

# %%
sns.histplot(x="MEDV",data=dataset,bins=50)
# Out:
# <AxesSubplot:xlabel='MEDV', ylabel='Count'>

# %% [markdown]
# ### Split Data Into Train , Test

# %%
x = dataset.drop("MEDV",axis=1)
y = dataset["MEDV"]

x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, test_size=0.25, random_state=SEED)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((379, 13), (127, 13), (379,), (127,))

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Linear Regression

# %%
linear_regression = linear_model.LinearRegression()
linear_regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr_pred = linear_regression.predict(x_test)

# %%
lr_sqr_error = metrics.mean_squared_error(y_test,lr_pred)

print('Linear Regression MSE :- ',lr_sqr_error)
# Out:
# Linear Regression MSE :-  22.098694827098164

# %% [markdown]
# ## SVR

# %%
svr_model = svm.SVR()
svr_model.fit(x_train,y_train)
# Out:
# SVR()

# %%
svr_pred = svr_model.predict(x_test)

# %%
svr_sqr_error = metrics.mean_squared_error(y_test,svr_pred)

print('SVR MSE :- ',svr_sqr_error)
# Out:
# SVR MSE :-  49.28419516700926

# %% [markdown]
# ## Random Forest Regressor

# %%
rfr_model = ensemble.RandomForestRegressor()
rfr_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rfr_pred = rfr_model.predict(x_test)

# %%
rfr_sqr_error = metrics.mean_squared_error(y_test,rfr_pred)

print('Random Forest Regressor MSE :- ',rfr_sqr_error)
# Out:
# Random Forest Regressor MSE :-  10.324669748031488

# %% [markdown]
# ## XGBoost Regressor

# %%
xgb_model = xgb.XGBRegressor()
xgb_model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
xgb_pred = xgb_model.predict(x_test)

# %%
xgb_sqr_error = metrics.mean_squared_error(y_test,xgb_pred)

print('XGBoost Regressor MSE :- ',xgb_sqr_error)
# Out:
# XGBoost Regressor MSE :-  10.061069900863131

# %% [markdown]
# # Model Evaluation

# %%
print("Linear Regression Error:",np.sqrt(lr_sqr_error))
print("Support Vector Machine Error:",np.sqrt(svr_sqr_error))
print("Random Forest Regressor Error:",np.sqrt(rfr_sqr_error))
print("XGBoost Regressor Error:",np.sqrt(xgb_sqr_error))
# Out:
# Linear Regression Error: 4.700924890603781
# Support Vector Machine Error: 7.020270305836468
# Random Forest Regressor Error: 3.2132024131746646
# XGBoost Regressor Error: 3.1719189619003716

# %% [markdown]
# #### we see that XGBoost Regressor has minimum error value
